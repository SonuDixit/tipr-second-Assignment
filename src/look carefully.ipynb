# %%
import numpy as np
from NN import NN
from matplotlib import pyplot as plt

# %%
net = NN()
input_x = np.asarray([[1,0]])
y_train = np.asarray([[0,1]])
l = net.fit_batch(input_x, y_train, epochs = 15)
# print(net.predict(input_x))
plt.plot(l)
plt.show()
# Out:
# epoch = 1 loss =0.7990065418291179
# epoch = 2 loss =0.7898598008792376
# epoch = 3 loss =0.7809016899825115
# epoch = 4 loss =0.7721262357630144
# epoch = 5 loss =0.7635277099642942
# epoch = 6 loss =0.7551006176410812
# epoch = 7 loss =0.7468396859794271
# epoch = 8 loss =0.7387398537101632
# epoch = 9 loss =0.7307962610825002
# epoch = 10 loss =0.7230042403664292
# epoch = 11 loss =0.7153593068543388
# epoch = 12 loss =0.7078571503339234
# epoch = 13 loss =0.7004936270060362
# epoch = 14 loss =0.6932647518226414
# epoch = 15 loss =0.6861666912214289
# training done

# %%
net = NN()
input_x = np.asarray([[1,0],[1,1],[0,1],[0,0]])
y_train = np.asarray([[0,1],[1,0],[0,1],[1,0]])
l = net.fit_batch(input_x, y_train, epochs = 200,lr = .1)
# print(net.predict(input_x))
plt.plot(l)
plt.show()
# Out:
# epoch = 1 loss =0.7110288525774241
# epoch = 2 loss =0.70371768251318
# epoch = 3 loss =0.7000139505186891
# epoch = 4 loss =0.6934104558137834
# epoch = 5 loss =0.6893509250680526
# epoch = 6 loss =0.6891140872875193
# epoch = 7 loss =0.6818325687537392
# epoch = 8 loss =0.6754451918118767
# epoch = 9 loss =0.6803772250366813
# epoch = 10 loss =0.672614169305494
# epoch = 11 loss =0.6656990234746777
# epoch = 12 loss =0.6576133209347219
# epoch = 13 loss =0.6609481851805485
# epoch = 14 loss =0.6448108510103326
# epoch = 15 loss =0.6419715170771305
# epoch = 16 loss =0.6448339224863902
# epoch = 17 loss =0.6407992169025726
# epoch = 18 loss =0.6295190255120224
# epoch = 19 loss =0.6171959179702295
# epoch = 20 loss =0.6141015521912689
# epoch = 21 loss =0.6182727212427144
# epoch = 22 loss =0.604285237619703
# epoch = 23 loss =0.6028922625139727
# epoch = 24 loss =0.5928295008500476
# epoch = 25 loss =0.5895117267207197
# epoch = 26 loss =0.5808923282494038
# ...

# %% [markdown]
# ## fitting XOR with one hidden layerhaving 3 nodes, using momentum, without momentum it takes more time to converge

# %%
net = NN(momentum = 0.8)
input_x = np.asarray([[1,0],[1,1],[0,1],[0,0]])
y_train = np.asarray([[0,1],[1,0],[0,1],[1,0]])
l = net.fit_batch(input_x, y_train, epochs = 200,lr = .4,batch_size=2)
# print(net.predict(input_x))
plt.plot(l)
plt.show()
# Out:
# epoch = 1 loss =0.6934778385203358
# epoch = 2 loss =0.6647467428574199
# epoch = 3 loss =0.6457969545354612
# epoch = 4 loss =0.6107780414681738
# epoch = 5 loss =0.5380334489035323
# epoch = 6 loss =0.4601651855971086
# epoch = 7 loss =0.506407845961867
# epoch = 8 loss =0.43214089500566977
# epoch = 9 loss =0.3937703989208437
# epoch = 10 loss =0.3999132061253087
# epoch = 11 loss =0.39611720076434004
# epoch = 12 loss =0.38657213592919304
# epoch = 13 loss =0.37553500234576354
# epoch = 14 loss =0.3893311874432157
# epoch = 15 loss =0.5135889527764829
# epoch = 16 loss =0.41683672449006937
# epoch = 17 loss =1.10757023694387
# epoch = 18 loss =1.0812351020120738
# epoch = 19 loss =0.6985355430265473
# epoch = 20 loss =0.5880339678496789
# epoch = 21 loss =0.5024354332170285
# epoch = 22 loss =0.5056952580280597
# epoch = 23 loss =0.5032396885075968
# epoch = 24 loss =0.4968179666089621
# epoch = 25 loss =0.4874217420568633
# epoch = 26 loss =0.485417340243334
# ...
