# %%
import numpy as np
from NN import NN
from Back_try import NNtry

# %%
net = NN()
input_x = np.asarray([[1,0],[1,1],[0,1],[0,0]])
y_train = np.asarray([[0,1],[0,0],[1,0],[1,1]])
net.fit_batch(input_x,y_train,epochs = 1700)
print(net.predict(input_x))
# Out:
# epoch = 1 loss =0.6931101388843257
# epoch = 2 loss =0.6931101293996436
# epoch = 3 loss =0.6931101199429736
# epoch = 4 loss =0.6931101105101998
# epoch = 5 loss =0.6931101010974403
# epoch = 6 loss =0.6931100917010368
# epoch = 7 loss =0.6931100823175425
# epoch = 8 loss =0.693110072943713
# epoch = 9 loss =0.6931100635764951
# epoch = 10 loss =0.6931100542130187
# epoch = 11 loss =0.6931100448505877
# epoch = 12 loss =0.6931100354866702
# epoch = 13 loss =0.6931100261188912
# epoch = 14 loss =0.6931100167450247
# epoch = 15 loss =0.6931100073629866
# epoch = 16 loss =0.6931099979708265
# epoch = 17 loss =0.6931099885667225
# epoch = 18 loss =0.693109979148973
# epoch = 19 loss =0.6931099697159915
# epoch = 20 loss =0.6931099602663009
# epoch = 21 loss =0.6931099507985274
# epoch = 22 loss =0.6931099413113954
# epoch = 23 loss =0.693109931803722
# epoch = 24 loss =0.6931099222744128
# epoch = 25 loss =0.6931099127224568
# epoch = 26 loss =0.693109903146922
# ...

# %%
net=NN()

# %%
net.layers[0].weights
# Out:
# array([[-0.05428153,  0.04986727,  0.01414892, -0.07531474],
#        [-0.02893001,  0.08257183, -0.12133396, -0.02144563]])

# %%
nn = NNtry()

# %%
nn.W_list[0]
# Out:
# array([[-0.05428153, -0.02893001],
#        [ 0.04986727,  0.08257183],
#        [ 0.01414892, -0.12133396],
#        [-0.07531474, -0.02144563]])
