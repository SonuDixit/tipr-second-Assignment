# %%
import os
from matplotlib.image import imread
import numpy as np
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from NN import NN
from helper_fns import prepare_train_test_cat_dog

# %%
path = os.getcwd()
data_path = os.path.join(os.path.dirname(path),"Data","Cat-Dog")

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
import cv2

# %%
total_data = []
total_label = []
for label in (["cat","dog"]):
    f = os.listdir(os.path.join(data_path,str(label)))
    for file_name in f:
        a = imread(os.path.join(data_path,str(label),file_name))
        a = rgb2gray(a)
        a = cv2.resize(a,(100,100),interpolation = cv2.INTER_AREA)
        a = a.reshape(a.shape[0] * a.shape[1], )
        total_data.append(a)
        if label == "cat":
            total_label.append(0)
        else:
            total_label.append(1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    total_data, total_label, test_size=0.30, random_state=42,shuffle = True)

# %%
len(X_train)
# Out:
# 17500

# %%
net_3 = NN(hidden_layer=[30,20,10], activation=["swish","relu","relu"], 
         input_dim=40000,output_dim=2)

# %%
for _ in range(1):
    for i in range(175):
        data_batch = np.asarray(X_train[i*100: (i+1) * 100])
        label_batch = np.asarray(y_train[i*100: (i+1) * 100])
        y_tr_one_hot = np.zeros((label_batch.shape[0],2))
        for j in range(label_batch.shape[0]):
            y_tr_one_hot[j,label_batch[j]] = 1
        lr = 0.0001
#         if i > 50 :
#             lr = 0.0001
#         if i> 120 :
#             lr = 0.001
        loss = net_3.fit_batch(data_batch,y_tr_one_hot,
                           epochs=1,lr=lr,batch_size=20)
        print(i)
# Out:
# H:\sonu\tipr\Assignment2\src\NN.py:8: RuntimeWarning: divide by zero encountered in log
#   return np.sum(-np.log(pred_array[np.where(true_array==1)]))
# epoch = 1 loss =inf
# training done
# 0
# epoch = 1 loss =7.836996155502664
# training done
# 1
# epoch = 1 loss =0.69318984051106
# training done
# 2
# epoch = 1 loss =0.6931688089143119
# training done
# 3
# epoch = 1 loss =0.6931396996111814
# training done
# 4
# epoch = 1 loss =0.6931746565199839
# training done
# 5
# epoch = 1 loss =0.6931142397647531
# training done
# 6
# epoch = 1 loss =0.6932182712597783
# training done
# 7
# epoch = 1 loss =0.6929918113480501
# training done
# 8
# epoch = 1 loss =0.6932385574609419
# training done
# 9
# epoch = 1 loss =0.6932316689330742
# training done
# 10
# epoch = 1 loss =0.6931437141999156
# training done
# 11
# epoch = 1 loss =0.6932563328231969
# training done
# 12
# epoch = 1 loss =0.6931707544093588
# training done
# 13
# epoch = 1 loss =0.6931488673491569
# training done
# 14
# epoch = 1 loss =0.6931026854615484
# training done
# 15
# epoch = 1 loss =0.6932340358956466
# training done
# 16
# epoch = 1 loss =0.6932175155856117
# training done
# 17
# epoch = 1 loss =0.6931254696740481
# training done
# 18
# epoch = 1 loss =0.6930244521552575
# training done
# 19
# epoch = 1 loss =0.6929304146052363
# training done
# 20
# epoch = 1 loss =0.6974346450291249
# training done
# 21
# epoch = 1 loss =0.6930624744719032
# training done
# 22
# epoch = 1 loss =0.6930565262425971
# training done
# 23
# epoch = 1 loss =0.6931224443759441
# training done
# 24
# epoch = 1 loss =0.6938179064267567
# training done
# 25
# epoch = 1 loss =0.6931141589137273
# training done
# 26
# epoch = 1 loss =0.6932688137444049
# training done
# 27
# epoch = 1 loss =0.6930652502266307
# training done
# 28
# epoch = 1 loss =0.6934280392808982
# training done
# 29
# epoch = 1 loss =0.692695979315699
# training done
# 30
# epoch = 1 loss =0.693272595760709
# training done
# 31
# epoch = 1 loss =0.6925692341306418
# training done
# 32
# epoch = 1 loss =0.6928699601844411
# training done
# 33
# epoch = 1 loss =0.6934129850346759
# training done
# 34
# epoch = 1 loss =0.692769222774305
# training done
# 35
# epoch = 1 loss =0.6931859783300068
# training done
# 36
# epoch = 1 loss =0.6933385160097434
# training done
# 37
# epoch = 1 loss =0.6935836142065027
# training done
# 38
# epoch = 1 loss =0.6932276501062521
# training done
# 39
# epoch = 1 loss =0.6937030201642387
# training done
# 40
# epoch = 1 loss =0.6924760692351881
# training done
# 41
# epoch = 1 loss =0.6927914894448342
# training done
# 42
# epoch = 1 loss =0.6933299177953859
# training done
# 43
# epoch = 1 loss =0.6930997140961891
# training done
# 44
# epoch = 1 loss =0.693023921494211
# training done
# 45
# epoch = 1 loss =0.6930835591117748
# training done
# 46
# epoch = 1 loss =0.692638089930681
# training done
# 47
# epoch = 1 loss =0.6935432675335664
# training done
# 48
# epoch = 1 loss =0.6926321214859122
# training done
# 49
# epoch = 1 loss =0.6924615517877819
# training done
# 50
# epoch = 1 loss =0.6941143019536719
# training done
# 51
# epoch = 1 loss =0.693527124769589
# training done
# 52
# epoch = 1 loss =0.6930773870303155
# training done
# 53
# epoch = 1 loss =0.6938743046864769
# training done
# 54
# epoch = 1 loss =0.6934834335083697
# training done
# 55
# epoch = 1 loss =0.6931115685267916
# training done
# 56
# epoch = 1 loss =0.6928641175201463
# training done
# 57
# epoch = 1 loss =0.693582233262502
# training done
# 58
# epoch = 1 loss =0.6931732555738978
# training done
# 59
# epoch = 1 loss =0.6928681182255749
# training done
# 60
# epoch = 1 loss =0.6932209903121758
# training done
# 61
# epoch = 1 loss =0.6929864205163762
# training done
# 62
# epoch = 1 loss =0.6926501395032431
# training done
# 63
# epoch = 1 loss =0.6941236114968351
# training done
# 64
# epoch = 1 loss =0.6932341711808293
# training done
# 65
# epoch = 1 loss =0.6932296520307557
# training done
# 66
# epoch = 1 loss =0.6931061940587804
# training done
# 67
# epoch = 1 loss =0.6936768537582474
# training done
# 68
# epoch = 1 loss =0.6932545130230539
# training done
# 69
# epoch = 1 loss =0.693295303105851
# training done
# 70
# epoch = 1 loss =0.6930169125133022
# training done
# 71
# epoch = 1 loss =0.6930139930096767
# training done
# 72
# epoch = 1 loss =0.6932043894406047
# training done
# 73
# epoch = 1 loss =0.6931527344739077
# training done
# 74
# epoch = 1 loss =0.692789271374495
# training done
# 75
# epoch = 1 loss =0.6933070717186354
# training done
# 76
# epoch = 1 loss =0.6933302002584695
# training done
# 77
# epoch = 1 loss =0.6929428858004233
# training done
# 78
# epoch = 1 loss =0.6933027003727892
# training done
# 79
# epoch = 1 loss =0.69336323192768
# training done
# 80
# epoch = 1 loss =0.693379012262901
# training done
# 81
# epoch = 1 loss =0.6930946951251982
# training done
# 82
# epoch = 1 loss =0.6932852094078461
# training done
# 83
# epoch = 1 loss =0.6930915573795403
# training done
# 84
# epoch = 1 loss =0.6932486145721783
# training done
# 85
# epoch = 1 loss =0.693181361240756
# training done
# 86
# epoch = 1 loss =0.6931725941059438
# training done
# 87
# epoch = 1 loss =0.6931024860490368
# training done
# 88
# epoch = 1 loss =0.6932271172192618
# training done
# 89
# epoch = 1 loss =0.6931618814734536
# training done
# 90
# epoch = 1 loss =0.6931523973080842
# training done
# 91
# epoch = 1 loss =0.6931943889118667
# training done
# 92
# epoch = 1 loss =0.6931457573686941
# training done
# 93
# epoch = 1 loss =0.6931745477704685
# training done
# 94
# epoch = 1 loss =0.6931590145219816
# training done
# 95
# epoch = 1 loss =0.6932182763454207
# training done
# 96
# epoch = 1 loss =0.6930653353356487
# training done
# 97
# epoch = 1 loss =0.6930704295662654
# training done
# 98
# epoch = 1 loss =0.692903765694296
# training done
# 99
# epoch = 1 loss =0.6932405388917405
# training done
# 100
# epoch = 1 loss =0.6931914502724714
# training done
# 101
# epoch = 1 loss =0.6932992225508721
# training done
# 102
# epoch = 1 loss =0.6932061148290305
# training done
# 103
# epoch = 1 loss =0.693052967907836
# training done
# 104
# epoch = 1 loss =0.6933559137704703
# training done
# 105
# epoch = 1 loss =0.6929910656414264
# training done
# 106
# epoch = 1 loss =0.6932212600764244
# training done
# 107
# epoch = 1 loss =0.6928728151388351
# training done
# 108
# epoch = 1 loss =0.6930658077137335
# training done
# 109
# epoch = 1 loss =0.6933957259429387
# training done
# 110
# epoch = 1 loss =0.6928874542231921
# training done
# 111
# epoch = 1 loss =0.6928211013892133
# training done
# 112
# epoch = 1 loss =0.6930224664299454
# training done
# 113
# epoch = 1 loss =0.6934808942049725
# training done
# 114
# epoch = 1 loss =0.6927202521836149
# training done
# 115
# epoch = 1 loss =0.6929767351325554
# training done
# 116
# epoch = 1 loss =0.692791873072259
# training done
# 117
# epoch = 1 loss =0.6937273281956174
# training done
# 118
# epoch = 1 loss =0.6932413956920331
# training done
# 119
# epoch = 1 loss =0.6931137992505072
# training done
# 120
# epoch = 1 loss =0.6937981570994216
# training done
# 121
# epoch = 1 loss =0.6932052289715152
# training done
# 122
# epoch = 1 loss =0.6932187140405138
# training done
# 123
# epoch = 1 loss =0.6932786151367499
# training done
# 124
# epoch = 1 loss =0.6933020270412662
# training done
# 125
# epoch = 1 loss =0.6933712938430334
# training done
# 126
# epoch = 1 loss =0.6932018451191055
# training done
# 127
# epoch = 1 loss =0.6932648325975369
# training done
# 128
# epoch = 1 loss =0.6931240150361208
# training done
# 129
# epoch = 1 loss =0.693145720383991
# training done
# 130
# epoch = 1 loss =0.6930472020254435
# training done
# 131
# epoch = 1 loss =0.6931226014024514
# training done
# 132
# epoch = 1 loss =0.6931248838842191
# training done
# 133
# epoch = 1 loss =0.6933676247260641
# training done
# 134
# epoch = 1 loss =0.6932113736645792
# training done
# 135
# epoch = 1 loss =0.693150019751511
# training done
# 136
# epoch = 1 loss =0.6931612452194993
# training done
# 137
# epoch = 1 loss =0.6931672637270345
# training done
# 138
# epoch = 1 loss =0.6931103161961863
# training done
# 139
# epoch = 1 loss =0.6932268317633042
# training done
# 140
# epoch = 1 loss =0.6931586240564238
# training done
# 141
# epoch = 1 loss =0.6931441296868307
# training done
# 142
# epoch = 1 loss =0.6930583777026186
# training done
# 143
# epoch = 1 loss =0.6932083230873157
# training done
# 144
# epoch = 1 loss =0.6931538056148672
# training done
# 145
# epoch = 1 loss =0.6930431322700769
# training done
# 146
# epoch = 1 loss =0.6931284759692758
# training done
# 147
# epoch = 1 loss =0.6930581106754923
# training done
# 148
# epoch = 1 loss =0.693378883658827
# training done
# 149
# epoch = 1 loss =0.6932911164443719
# training done
# 150
# epoch = 1 loss =0.6929468629058079
# training done
# 151
# epoch = 1 loss =0.6932875868347754
# training done
# 152
# epoch = 1 loss =0.693242589449362
# training done
# 153
# epoch = 1 loss =0.6932209797538142
# training done
# 154
# epoch = 1 loss =0.6931551534749576
# training done
# 155
# epoch = 1 loss =0.6930955098145108
# training done
# 156
# epoch = 1 loss =0.6931061309473653
# training done
# 157
# epoch = 1 loss =0.6932395479596457
# training done
# 158
# epoch = 1 loss =0.693193047429974
# training done
# 159
# epoch = 1 loss =0.693069550890123
# training done
# 160
# epoch = 1 loss =0.692767962479428
# training done
# 161
# epoch = 1 loss =0.6932945284493899
# training done
# 162
# epoch = 1 loss =0.693377178096712
# training done
# 163
# epoch = 1 loss =0.6931444932951643
# training done
# 164
# epoch = 1 loss =0.6930851610611676
# training done
# 165
# epoch = 1 loss =0.6931987198040673
# training done
# 166
# epoch = 1 loss =0.6932253994802672
# training done
# 167
# epoch = 1 loss =0.6931100533546691
# training done
# 168
# epoch = 1 loss =0.6933197951381603
# training done
# 169
# epoch = 1 loss =0.6930095279936824
# training done
# 170
# epoch = 1 loss =0.6932975622552885
# training done
# 171
# epoch = 1 loss =0.6931089166837865
# training done
# 172
# epoch = 1 loss =0.6928670664539527
# training done
# 173
# epoch = 1 loss =0.693469428426671
# training done
# 174

# %% [markdown]
# ## second epoch with _increased_ learning rate

# %%
for i in range(175):
    data_batch = np.asarray(X_train[i*100: (i+1) * 100])
    label_batch = np.asarray(y_train[i*100: (i+1) * 100])
    y_tr_one_hot = np.zeros((label_batch.shape[0],2))
    for j in range(label_batch.shape[0]):
        y_tr_one_hot[j,label_batch[j]] = 1
    lr = 0.001
#         if i > 50 :
#             lr = 0.0001
#         if i> 120 :
#             lr = 0.001
    loss = net_3.fit_batch(data_batch,y_tr_one_hot,
                       epochs=1,lr=lr,batch_size=20)
    print(i)
# Out:
# epoch = 1 loss =0.6931730281254324
# training done
# 0
# epoch = 1 loss =0.6938636960045561
# training done
# 1
# epoch = 1 loss =0.6934163144363698
# training done
# 2
# epoch = 1 loss =0.6935230086768747
# training done
# 3
# epoch = 1 loss =0.6930956570131062
# training done
# 4
# epoch = 1 loss =0.6931797900320231
# training done
# 5
# epoch = 1 loss =0.6931285345657936
# training done
# 6
# epoch = 1 loss =0.6937471027868416
# training done
# 7
# epoch = 1 loss =0.6918074035969352
# training done
# 8
# epoch = 1 loss =0.6938546488004667
# training done
# 9
# epoch = 1 loss =0.6938935863683469
# training done
# 10
# epoch = 1 loss =0.6931676982842252
# training done
# 11
# epoch = 1 loss =0.6943569190811452
# training done
# 12
# epoch = 1 loss =0.693384817785184
# training done
# 13
# epoch = 1 loss =0.692616712917457
# training done
# 14
# epoch = 1 loss =0.692564300578278
# training done
# 15
# epoch = 1 loss =0.6940618545004906
# training done
# 16
# epoch = 1 loss =0.6939242185773393
# training done
# 17
# epoch = 1 loss =0.6929640355001466
# training done
# 18
# epoch = 1 loss =0.6917852401422757
# training done
# 19
# epoch = 1 loss =0.6910707918479152
# training done
# 20
# epoch = 1 loss =0.6894750948469026
# training done
# 21
# epoch = 1 loss =0.6929192986497522
# training done
# 22
# epoch = 1 loss =0.6926938902716857
# training done
# 23
# epoch = 1 loss =0.6932437611480593
# training done
# 24
# epoch = 1 loss =0.6983726287370747
# training done
# 25
# epoch = 1 loss =0.6929754882646422
# training done
# 26
# epoch = 1 loss =0.6943611808165621
# training done
# 27
# epoch = 1 loss =0.6929123351939519
# training done
# 28
# epoch = 1 loss =0.695295702120228
# training done
# 29
# epoch = 1 loss =0.6906138968378148
# training done
# 30
# epoch = 1 loss =0.6944289943693436
# training done
# 31
# epoch = 1 loss =0.6894086592965665
# training done
# 32
# epoch = 1 loss =0.6916165169599376
# training done
# 33
# epoch = 1 loss =0.6957070456496299
# training done
# 34
# epoch = 1 loss =0.6911315825389649
# training done
# 35
# epoch = 1 loss =0.693541102418466
# training done
# 36
# epoch = 1 loss =0.6944870886367795
# training done
# 37
# epoch = 1 loss =0.6957080639204386
# training done
# 38
# epoch = 1 loss =0.6937189395744398
# training done
# 39
# epoch = 1 loss =0.6954626774499957
# training done
# 40
# epoch = 1 loss =0.6907538291189667
# training done
# 41
# epoch = 1 loss =0.6915821831796164
# training done
# 42
# epoch = 1 loss =0.6943034994461432
# training done
# 43
# epoch = 1 loss =0.6930554959040941
# training done
# 44
# epoch = 1 loss =0.692601366416423
# training done
# 45
# epoch = 1 loss =0.693277054817438
# training done
# 46
# epoch = 1 loss =0.6910090697528452
# training done
# 47
# epoch = 1 loss =0.6953896684045381
# training done
# 48
# epoch = 1 loss =0.6909324149231767
# training done
# 49
# epoch = 1 loss =0.6898609190648852
# training done
# 50
# epoch = 1 loss =0.6983539676519477
# training done
# 51
# epoch = 1 loss =0.6948564453565443
# training done
# 52
# epoch = 1 loss =0.6930468010852963
# training done
# 53
# epoch = 1 loss =0.6954110557706851
# training done
# 54
# epoch = 1 loss =0.6936555911971959
# training done
# 55
# epoch = 1 loss =0.6933191369409069
# training done
# 56
# epoch = 1 loss =0.6930307893374943
# training done
# 57
# epoch = 1 loss =0.6938686816043311
# training done
# 58
# epoch = 1 loss =0.6935258580357035
# training done
# 59
# epoch = 1 loss =0.6931403396214744
# training done
# 60
# epoch = 1 loss =0.6934777636603436
# training done
# 61
# epoch = 1 loss =0.6932749851586477
# training done
# 62
# epoch = 1 loss =0.6920650229447337
# training done
# 63
# epoch = 1 loss =0.6953901826793724
# training done
# 64
# epoch = 1 loss =0.6931822918765538
# training done
# 65
# epoch = 1 loss =0.6932654720403328
# training done
# 66
# epoch = 1 loss =0.6933708434310877
# training done
# 67
# epoch = 1 loss =0.6921695127332221
# training done
# 68
# epoch = 1 loss =0.692758517689138
# training done
# 69
# epoch = 1 loss =0.6916390891927793
# training done
# 70
# epoch = 1 loss =0.6959625636972119
# training done
# 71
# epoch = 1 loss =0.6942783032733617
# training done
# 72
# epoch = 1 loss =0.693190074768806
# training done
# 73
# epoch = 1 loss =0.693228659077804
# training done
# 74
# epoch = 1 loss =0.6937546353910132
# training done
# 75
# epoch = 1 loss =0.6933982744493558
# training done
# 76
# epoch = 1 loss =0.6931749861080806
# training done
# 77
# epoch = 1 loss =0.6935217361266791
# training done
# 78
# epoch = 1 loss =0.6932583242884265
# training done
# 79
# epoch = 1 loss =0.6931452496828641
# training done
# 80
# epoch = 1 loss =0.69244458418281
# training done
# 81
# epoch = 1 loss =0.6940581217067902
# training done
# 82
# epoch = 1 loss =0.6921932786339434
# training done
# 83
# epoch = 1 loss =0.6943658286079905
# training done
# 84
# epoch = 1 loss =0.6922535396454619
# training done
# 85
# epoch = 1 loss =0.6937907814387079
# training done
# 86
# epoch = 1 loss =0.6932914255733482
# training done
# 87
# epoch = 1 loss =0.6944984600436709
# training done
# 88
# epoch = 1 loss =0.6921730931294587
# training done
# 89
# epoch = 1 loss =0.6906707245778155
# training done
# 90
# epoch = 1 loss =0.6931339471612468
# training done
# 91
# epoch = 1 loss =0.695647362123928
# training done
# 92
# epoch = 1 loss =0.6941729704727675
# training done
# 93
# epoch = 1 loss =0.6926646131772032
# training done
# 94
# epoch = 1 loss =0.6938185123739247
# training done
# 95
# epoch = 1 loss =0.6930408789116782
# training done
# 96
# epoch = 1 loss =0.6948328727635559
# training done
# 97
# epoch = 1 loss =0.6931266663192672
# training done
# 98
# epoch = 1 loss =0.6924121555679814
# training done
# 99
# epoch = 1 loss =0.6936318859899299
# training done
# 100
# epoch = 1 loss =0.6936678779788207
# training done
# 101
# epoch = 1 loss =0.6936501359767325
# training done
# 102
# epoch = 1 loss =0.693376653277853
# training done
# 103
# epoch = 1 loss =0.6935576225124676
# training done
# 104
# epoch = 1 loss =0.6934338485090347
# training done
# 105
# epoch = 1 loss =0.693452165051354
# training done
# 106
# epoch = 1 loss =0.6936872926330089
# training done
# 107
# epoch = 1 loss =0.6925132774596553
# training done
# 108
# epoch = 1 loss =0.6931271192211946
# training done
# 109
# epoch = 1 loss =0.6942236315461652
# training done
# 110
# epoch = 1 loss =0.6921224062494846
# training done
# 111
# epoch = 1 loss =0.6915605609837825
# training done
# 112
# epoch = 1 loss =0.6927824765514253
# training done
# 113
# epoch = 1 loss =0.6950522869249753
# training done
# 114
# epoch = 1 loss =0.6911670835758676
# training done
# 115
# epoch = 1 loss =0.6922446391043741
# training done
# 116
# epoch = 1 loss =0.691403492044591
# training done
# 117
# epoch = 1 loss =0.6964250571349097
# training done
# 118
# epoch = 1 loss =0.6937471685335203
# training done
# 119
# epoch = 1 loss =0.6930876306361256
# training done
# 120
# epoch = 1 loss =0.6956190607326049
# training done
# 121
# epoch = 1 loss =0.6934897438754397
# training done
# 122
# epoch = 1 loss =0.6934194555341517
# training done
# 123
# epoch = 1 loss =0.6932575637082518
# training done
# 124
# epoch = 1 loss =0.6934535425952737
# training done
# 125
# epoch = 1 loss =0.6927080964655249
# training done
# 126
# epoch = 1 loss =0.6929949122140094
# training done
# 127
# epoch = 1 loss =0.6915501856906693
# training done
# 128
# epoch = 1 loss =0.6951456921604126
# training done
# 129
# epoch = 1 loss =0.6934613956532024
# training done
# 130
# epoch = 1 loss =0.6938917576472776
# training done
# 131
# epoch = 1 loss =0.6933035982047224
# training done
# 132
# epoch = 1 loss =0.6932780993739541
# training done
# 133
# epoch = 1 loss =0.6926106773899038
# training done
# 134
# epoch = 1 loss =0.6921688120124097
# training done
# 135
# epoch = 1 loss =0.6935891605821586
# training done
# 136
# epoch = 1 loss =0.6913067073329501
# training done
# 137
# epoch = 1 loss =0.6936357818256211
# training done
# 138
# epoch = 1 loss =0.6919607360894179
# training done
# 139
# epoch = 1 loss =0.6954693816730877
# training done
# 140
# epoch = 1 loss =0.6932873389342546
# training done
# 141
# epoch = 1 loss =0.6928748531384289
# training done
# 142
# epoch = 1 loss =0.6912504645103413
# training done
# 143
# epoch = 1 loss =0.6938002852147872
# training done
# 144
# epoch = 1 loss =0.693348085391726
# training done
# 145
# epoch = 1 loss =0.6914036511516192
# training done
# 146
# epoch = 1 loss =0.6930179311933253
# training done
# 147
# epoch = 1 loss =0.6920399527879976
# training done
# 148
# epoch = 1 loss =0.6960843345336457
# training done
# 149
# epoch = 1 loss =0.6952027967669175
# training done
# 150
# epoch = 1 loss =0.691163133385279
# training done
# 151
# epoch = 1 loss =0.6950902997489518
# training done
# 152
# epoch = 1 loss =0.6943231927017203
# training done
# 153
# epoch = 1 loss =0.6940542293120912
# training done
# 154
# epoch = 1 loss =0.6931103964554128
# training done
# 155
# epoch = 1 loss =0.6924328672886138
# training done
# 156
# epoch = 1 loss =0.6929185289726629
# training done
# 157
# epoch = 1 loss =0.6939626285288187
# training done
# 158
# epoch = 1 loss =0.6937357315621239
# training done
# 159
# epoch = 1 loss =0.6926630955212838
# training done
# 160
# epoch = 1 loss =0.6900482735359571
# training done
# 161
# epoch = 1 loss =0.6946597332281054
# training done
# 162
# epoch = 1 loss =0.6955088237215414
# training done
# 163
# epoch = 1 loss =0.6931170538466239
# training done
# 164
# epoch = 1 loss =0.6928174310493566
# training done
# 165
# epoch = 1 loss =0.6934451992053333
# training done
# 166
# epoch = 1 loss =0.6939198880990582
# training done
# 167
# epoch = 1 loss =0.6928484469498098
# training done
# 168
# epoch = 1 loss =0.6942433152262715
# training done
# 169
# epoch = 1 loss =0.6926984183978129
# training done
# 170
# epoch = 1 loss =0.6939836307748506
# training done
# 171
# epoch = 1 loss =0.6933802196766125
# training done
# 172
# epoch = 1 loss =0.6916496480725371
# training done
# 173
# epoch = 1 loss =0.6952163134846542
# training done
# 174

# %%
pred_vals = net_3.predict(np.asarray(X_test))
# for test_data in X_test:
#     pred_vals.append(net_3.predict(np.asarray(test_data)))
    
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,pred_vals))
from sklearn.metrics import f1_score
print(f1_score(y_test, pred_vals, average='macro'))
f1_score(y_test, pred_vals, average='micro')
# Out:
# 0.4997333333333333
# 0.3332147937411095
# C:\Users\vissim\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.4997333333333333

# %%
pred_vals
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
net_4 = NN(hidden_layer=[100, 60, 40], activation=["relu","relu","relu"], 
         input_dim=40000,output_dim=2,momentum = 0.8)

# %%
for _ in range(1):
    for i in range(15):
        data_batch = np.asarray(X_train[i*100: (i+1) * 100])
        label_batch = np.asarray(y_train[i*100: (i+1) * 100])
        y_tr_one_hot = np.zeros((label_batch.shape[0],2))
        for j in range(label_batch.shape[0]):
            y_tr_one_hot[j,label_batch[j]] = 1
        lr = 0.0001
#         if i > 50 :
#             lr = 0.0001
        if i> 3 :
            lr = 0.001
        if i>8:
            lr = 0.01
        loss = net_4.fit_batch(data_batch,y_tr_one_hot,
                           epochs=1,lr=lr,batch_size=20)
        print(i)
# Out:
# epoch = 1 loss =1.5671016278700864
# training done
# 0
# epoch = 1 loss =2.5226246070045706
# training done
# 1
# epoch = 1 loss =0.722802385308996
# training done
# 2
# epoch = 1 loss =0.7105658432889206
# training done
# 3
# epoch = 1 loss =0.6920124566383398
# training done
# 4
# epoch = 1 loss =0.682371034637332
# training done
# 5
# H:\sonu\tipr\Assignment2\src\activation.py:21: RuntimeWarning: invalid value encountered in true_divide
#   return np.exp(x+1.0) / np.sum(np.exp(x+1.0))
# H:\sonu\tipr\Assignment2\src\NN.py:8: RuntimeWarning: divide by zero encountered in log
#   return np.sum(-np.log(pred_array[np.where(true_array==1)]))
# H:\sonu\tipr\Assignment2\src\activation.py:36: RuntimeWarning: invalid value encountered in less
#   zero_index = np.where(x < 0)
# H:\sonu\tipr\Assignment2\src\activation.py:44: RuntimeWarning: invalid value encountered in greater
#   one_index = np.where(x > 0.0)
# epoch = 1 loss =nan
# training done
# 6
# epoch = 1 loss =nan
# training done
# 7
# epoch = 1 loss =nan
# training done
# 8
# epoch = 1 loss =nan
# training done
# 9
# epoch = 1 loss =nan
# training done
# 10
# epoch = 1 loss =nan
# training done
# 11
# epoch = 1 loss =nan
# training done
# 12
# epoch = 1 loss =nan
# training done
# 13
# epoch = 1 loss =nan
# training done
# 14

# %%
for e in range(2):
    for i in range(175):
        data_batch = np.asarray(X_train[i*100: (i+1) * 100])
        label_batch = np.asarray(y_train[i*100: (i+1) * 100])
        y_tr_one_hot = np.zeros((label_batch.shape[0],2))
        for j in range(label_batch.shape[0]):
            y_tr_one_hot[j,label_batch[j]] = 1
        lr = 0.01
#         if i > 50 :
#             lr = 0.0001
#         if i> 120 :
#             lr = 0.001
        loss = net_4.fit_batch(data_batch,y_tr_one_hot,
                           epochs=1,lr=lr,batch_size=20)
        print(i,e)
# Out:
# epoch = 1 loss =0.6922141167582713
# training done
# 0 0
# epoch = 1 loss =0.7015129580682103
# training done
# 1 0
# epoch = 1 loss =0.6957047075889545
# training done
# 2 0
# epoch = 1 loss =0.6973591565494439
# training done
# 3 0
# epoch = 1 loss =0.6938138265723502
# training done
# 4 0
# epoch = 1 loss =0.6937677129669503
# training done
# 5 0
# epoch = 1 loss =0.6959493828050127
# training done
# 6 0
# epoch = 1 loss =0.6960226817759505
# training done
# 7 0
# epoch = 1 loss =0.689098667209856
# training done
# 8 0
# epoch = 1 loss =0.698601927355632
# training done
# 9 0
# epoch = 1 loss =0.6948999670886326
# training done
# 10 0
# epoch = 1 loss =0.6947838924397876
# training done
# 11 0
# epoch = 1 loss =0.6960070379634863
# training done
# 12 0
# epoch = 1 loss =0.6940470692921598
# training done
# 13 0
# epoch = 1 loss =0.6847079630858773
# training done
# 14 0
# epoch = 1 loss =0.6920870332600946
# training done
# 15 0
# epoch = 1 loss =0.7020921782650663
# training done
# 16 0
# epoch = 1 loss =0.6977240035430013
# training done
# 17 0
# epoch = 1 loss =0.6946649640272743
# training done
# 18 0
# epoch = 1 loss =0.6890799816950093
# training done
# 19 0
# epoch = 1 loss =0.6869238442325251
# training done
# 20 0
# epoch = 1 loss =0.6819429078343812
# training done
# 21 0
# epoch = 1 loss =0.7016863894643722
# training done
# 22 0
# epoch = 1 loss =0.6970636683156886
# training done
# 23 0
# epoch = 1 loss =0.6969018574067127
# training done
# 24 0
# epoch = 1 loss =6.680431986207435
# training done
# 25 0
# epoch = 1 loss =0.7402301866622173
# training done
# 26 0
# epoch = 1 loss =0.6960579312403948
# training done
# 27 0
# epoch = 1 loss =0.6986694088992154
# training done
# 28 0
# epoch = 1 loss =0.6926316423183123
# training done
# 29 0
# epoch = 1 loss =0.6976198254392046
# training done
# 30 0
# epoch = 1 loss =0.698430486401608
# training done
# 31 0
# epoch = 1 loss =0.6871353620387882
# training done
# 32 0
# epoch = 1 loss =0.6924813979992918
# training done
# 33 0
# epoch = 1 loss =0.7034634439076171
# training done
# 34 0
# epoch = 1 loss =0.6928947543932503
# training done
# 35 0
# epoch = 1 loss =2.255955835417724
# training done
# 36 0
# epoch = 1 loss =0.6940870313053668
# training done
# 37 0
# epoch = 1 loss =0.694091424495894
# training done
# 38 0
# epoch = 1 loss =0.694329271752448
# training done
# 39 0
# epoch = 1 loss =0.6854910440757419
# training done
# 40 0
# epoch = 1 loss =0.7042415214898264
# training done
# 41 0
# epoch = 1 loss =0.6908447239998052
# training done
# 42 0
# epoch = 1 loss =0.697777620696844
# training done
# 43 0
# epoch = 1 loss =0.6939424505939911
# training done
# 44 0
# epoch = 1 loss =0.6926589661900642
# training done
# 45 0
# epoch = 1 loss =0.6964884666719283
# training done
# 46 0
# epoch = 1 loss =0.6912349645541545
# training done
# 47 0
# epoch = 1 loss =0.6985738756332041
# training done
# 48 0
# epoch = 1 loss =0.6918931563681591
# training done
# 49 0
# epoch = 1 loss =0.6867205359062774
# training done
# 50 0
# epoch = 1 loss =0.704975293765304
# training done
# 51 0
# epoch = 1 loss =0.6929990674019288
# training done
# 52 0
# epoch = 1 loss =0.6946061881761517
# training done
# 53 0
# epoch = 1 loss =0.6891218843433383
# training done
# 54 0
# epoch = 1 loss =0.6898290299648857
# training done
# 55 0
# epoch = 1 loss =0.698959840533061
# training done
# 56 0
# epoch = 1 loss =0.6969143316156972
# training done
# 57 0
# epoch = 1 loss =0.6956553727971757
# training done
# 58 0
# epoch = 1 loss =0.6969236626144089
# training done
# 59 0
# epoch = 1 loss =0.6942675175191967
# training done
# 60 0
# epoch = 1 loss =0.6958801655130352
# training done
# 61 0
# epoch = 1 loss =0.6966675658202842
# training done
# 62 0
# epoch = 1 loss =0.6892704104566788
# training done
# 63 0
# epoch = 1 loss =0.6991489307589828
# training done
# 64 0
# epoch = 1 loss =0.6942144070029416
# training done
# 65 0
# epoch = 1 loss =0.694731990198981
# training done
# 66 0
# epoch = 1 loss =0.6958546903274219
# training done
# 67 0
# epoch = 1 loss =0.6855036947244367
# training done
# 68 0
# epoch = 1 loss =0.6948154070873355
# training done
# 69 0
# epoch = 1 loss =0.6894201325586442
# training done
# 70 0
# epoch = 1 loss =0.707525474762523
# training done
# 71 0
# epoch = 1 loss =0.6927872253730902
# training done
# 72 0
# epoch = 1 loss =0.6959800857046077
# training done
# 73 0
# epoch = 1 loss =0.6938604031035748
# training done
# 74 0
# epoch = 1 loss =0.6874868884487287
# training done
# 75 0
# epoch = 1 loss =0.7004150702884908
# training done
# 76 0
# epoch = 1 loss =0.6956926421327103
# training done
# 77 0
# epoch = 1 loss =0.6942814946860594
# training done
# 78 0
# epoch = 1 loss =0.6949239005866745
# training done
# 79 0
# epoch = 1 loss =0.6944719161427758
# training done
# 80 0
# epoch = 1 loss =0.6907714325898547
# training done
# 81 0
# epoch = 1 loss =0.7016038289228865
# training done
# 82 0
# epoch = 1 loss =0.69155072145481
# training done
# 83 0
# epoch = 1 loss =0.7000092175119422
# training done
# 84 0
# epoch = 1 loss =0.6928715593529795
# training done
# 85 0
# epoch = 1 loss =0.6996867907387734
# training done
# 86 0
# epoch = 1 loss =0.6958943648329587
# training done
# 87 0
# epoch = 1 loss =0.696219759596992
# training done
# 88 0
# epoch = 1 loss =0.6940170479059798
# training done
# 89 0
# epoch = 1 loss =0.6871192520651621
# training done
# 90 0
# epoch = 1 loss =0.6961235700959705
# training done
# 91 0
# epoch = 1 loss =0.6988604848605301
# training done
# 92 0
# epoch = 1 loss =0.6938368217951566
# training done
# 93 0
# epoch = 1 loss =0.6963006013136561
# training done
# 94 0
# epoch = 1 loss =0.6942860389200577
# training done
# 95 0
# epoch = 1 loss =0.6937633670505186
# training done
# 96 0
# epoch = 1 loss =0.691320425905624
# training done
# 97 0
# epoch = 1 loss =0.6906410921348225
# training done
# 98 0
# epoch = 1 loss =0.6856358271991673
# training done
# 99 0
# epoch = 1 loss =0.700724891903043
# training done
# 100 0
# epoch = 1 loss =0.6983039627802825
# training done
# 101 0
# epoch = 1 loss =0.695066701598855
# training done
# 102 0
# epoch = 1 loss =0.6942741993893446
# training done
# 103 0
# epoch = 1 loss =0.6993334537006685
# training done
# 104 0
# epoch = 1 loss =0.6927932515378806
# training done
# 105 0
# epoch = 1 loss =0.6991794521134352
# training done
# 106 0
# epoch = 1 loss =0.6978476538683636
# training done
# 107 0
# epoch = 1 loss =0.6911616929587525
# training done
# 108 0
# epoch = 1 loss =0.6957487201083267
# training done
# 109 0
# epoch = 1 loss =0.6975613494971017
# training done
# 110 0
# epoch = 1 loss =0.6915920785161092
# training done
# 111 0
# epoch = 1 loss =0.6876180828356182
# training done
# 112 0
# epoch = 1 loss =0.6950348951085256
# training done
# 113 0
# epoch = 1 loss =0.6997407797158195
# training done
# 114 0
# epoch = 1 loss =0.6902816805981975
# training done
# 115 0
# epoch = 1 loss =0.6923071473752066
# training done
# 116 0
# epoch = 1 loss =0.6915642722553854
# training done
# 117 0
# epoch = 1 loss =0.6988932518511223
# training done
# 118 0
# epoch = 1 loss =0.6944239280641663
# training done
# 119 0
# epoch = 1 loss =0.6946448827343024
# training done
# 120 0
# epoch = 1 loss =0.688769440066809
# training done
# 121 0
# epoch = 1 loss =0.6970701228966321
# training done
# 122 0
# epoch = 1 loss =0.6956916441334942
# training done
# 123 0
# epoch = 1 loss =0.692928990096101
# training done
# 124 0
# epoch = 1 loss =0.6947881169263088
# training done
# 125 0
# epoch = 1 loss =0.6888800356552599
# training done
# 126 0
# epoch = 1 loss =0.694730465644195
# training done
# 127 0
# epoch = 1 loss =0.6864614825030732
# training done
# 128 0
# epoch = 1 loss =0.7038949295104132
# training done
# 129 0
# epoch = 1 loss =0.6935928889043939
# training done
# 130 0
# epoch = 1 loss =0.6909045615586014
# training done
# 131 0
# epoch = 1 loss =0.6942241220787808
# training done
# 132 0
# epoch = 1 loss =0.6939666263507717
# training done
# 133 0
# epoch = 1 loss =0.6956977966980449
# training done
# 134 0
# epoch = 1 loss =0.6902719995083761
# training done
# 135 0
# epoch = 1 loss =0.6969056306017929
# training done
# 136 0
# epoch = 1 loss =0.6888823951641925
# training done
# 137 0
# epoch = 1 loss =0.6973176870406822
# training done
# 138 0
# epoch = 1 loss =0.6921010844390763
# training done
# 139 0
# epoch = 1 loss =0.6993311108273571
# training done
# 140 0
# epoch = 1 loss =0.6967545193951048
# training done
# 141 0
# epoch = 1 loss =0.6955069093755134
# training done
# 142 0
# epoch = 1 loss =0.6915563020862233
# training done
# 143 0
# epoch = 1 loss =0.6948699957091745
# training done
# 144 0
# epoch = 1 loss =0.6934935259676601
# training done
# 145 0
# epoch = 1 loss =0.6914974036672921
# training done
# 146 0
# epoch = 1 loss =0.693919251090375
# training done
# 147 0
# epoch = 1 loss =0.6916132155584239
# training done
# 148 0
# epoch = 1 loss =0.6968611224405101
# training done
# 149 0
# epoch = 1 loss =0.6911406784288892
# training done
# 150 0
# epoch = 1 loss =0.7013419029390592
# training done
# 151 0
# epoch = 1 loss =0.6988791837262035
# training done
# 152 0
# epoch = 1 loss =0.692939610582009
# training done
# 153 0
# epoch = 1 loss =0.6909049612827262
# training done
# 154 0
# epoch = 1 loss =0.6980965911145819
# training done
# 155 0
# epoch = 1 loss =0.6955943697144459
# training done
# 156 0
# epoch = 1 loss =0.6938389290434785
# training done
# 157 0
# epoch = 1 loss =0.6969048488114977
# training done
# 158 0
# epoch = 1 loss =0.6947499639279218
# training done
# 159 0
# epoch = 1 loss =0.6949702347512027
# training done
# 160 0
# epoch = 1 loss =0.6826916918900422
# training done
# 161 0
# epoch = 1 loss =0.7027834616177564
# training done
# 162 0
# epoch = 1 loss =0.7003883313136546
# training done
# 163 0
# epoch = 1 loss =0.6947054952831437
# training done
# 164 0
# epoch = 1 loss =0.6935940568309698
# training done
# 165 0
# epoch = 1 loss =0.6955914875589704
# training done
# 166 0
# epoch = 1 loss =0.6960206197129323
# training done
# 167 0
# epoch = 1 loss =0.6938798258796187
# training done
# 168 0
# epoch = 1 loss =0.6942685299863106
# training done
# 169 0
# epoch = 1 loss =0.6971275431888896
# training done
# 170 0
# epoch = 1 loss =0.6950420189600045
# training done
# 171 0
# epoch = 1 loss =0.6980084885191014
# training done
# 172 0
# epoch = 1 loss =0.6912712552475827
# training done
# 173 0
# epoch = 1 loss =0.6974970153893777
# training done
# 174 0
# epoch = 1 loss =0.6890601359955743
# training done
# 0 1
# epoch = 1 loss =0.7033788282645363
# training done
# 1 1
# epoch = 1 loss =0.6951629813854329
# training done
# 2 1
# epoch = 1 loss =0.6959328044210941
# training done
# 3 1
# epoch = 1 loss =0.6958556857986059
# training done
# 4 1
# epoch = 1 loss =0.6970672618186208
# training done
# 5 1
# epoch = 1 loss =0.6934243317220796
# training done
# 6 1
# epoch = 1 loss =0.7001879109707168
# training done
# 7 1
# epoch = 1 loss =0.6893072087786405
# training done
# 8 1
# epoch = 1 loss =0.6981979234344589
# training done
# 9 1
# epoch = 1 loss =0.695038320035164
# training done
# 10 1
# epoch = 1 loss =0.6954926214968693
# training done
# 11 1
# epoch = 1 loss =0.6937459026267452
# training done
# 12 1
# epoch = 1 loss =0.6934420416357447
# training done
# 13 1
# epoch = 1 loss =0.6833667108263569
# training done
# 14 1
# epoch = 1 loss =0.6921603774759246
# training done
# 15 1
# epoch = 1 loss =0.7008183851753712
# training done
# 16 1
# epoch = 1 loss =0.6944614263598293
# training done
# 17 1
# epoch = 1 loss =0.6975065810982745
# training done
# 18 1
# epoch = 1 loss =0.6918675598260231
# training done
# 19 1
# epoch = 1 loss =0.6873349215686955
# training done
# 20 1
# epoch = 1 loss =0.6813750948376301
# training done
# 21 1
# epoch = 1 loss =0.6960123687738795
# training done
# 22 1
# epoch = 1 loss =0.6968058823341632
# training done
# 23 1
# epoch = 1 loss =0.6950976705652897
# training done
# 24 1
# epoch = 1 loss =0.6997398707138813
# training done
# 25 1
# epoch = 1 loss =0.6946923652898238
# training done
# 26 1
# epoch = 1 loss =0.6943996415895449
# training done
# 27 1
# epoch = 1 loss =0.6945483655645444
# training done
# 28 1
# epoch = 1 loss =0.6920861119370546
# training done
# 29 1
# epoch = 1 loss =0.6966708655996838
# training done
# 30 1
# epoch = 1 loss =0.6958346208431345
# training done
# 31 1
# epoch = 1 loss =0.6867497158304867
# training done
# 32 1
# epoch = 1 loss =0.6911413192698593
# training done
# 33 1
# epoch = 1 loss =0.6992843321592956
# training done
# 34 1
# epoch = 1 loss =0.6921017736614332
# training done
# 35 1
# epoch = 1 loss =0.6975213549660587
# training done
# 36 1
# epoch = 1 loss =0.6988276120320112
# training done
# 37 1
# epoch = 1 loss =0.6936255597094394
# training done
# 38 1
# epoch = 1 loss =0.6949452067573335
# training done
# 39 1
# epoch = 1 loss =0.6859240621804978
# training done
# 40 1
# epoch = 1 loss =0.7123181332947942
# training done
# 41 1
# epoch = 1 loss =0.6901205590226734
# training done
# 42 1
# epoch = 1 loss =0.6967569633851959
# training done
# 43 1
# epoch = 1 loss =0.693375586736035
# training done
# 44 1
# epoch = 1 loss =0.6941269523740076
# training done
# 45 1
# epoch = 1 loss =0.6953385317621716
# training done
# 46 1
# epoch = 1 loss =0.690065059026976
# training done
# 47 1
# epoch = 1 loss =0.7004646480080835
# training done
# 48 1
# epoch = 1 loss =0.6921689405689034
# training done
# 49 1
# epoch = 1 loss =0.6879180844686585
# training done
# 50 1
# epoch = 1 loss =0.7014849183538633
# training done
# 51 1
# epoch = 1 loss =0.6914613059697449
# training done
# 52 1
# epoch = 1 loss =0.6960540372416552
# training done
# 53 1
# epoch = 1 loss =0.6865801765994414
# training done
# 54 1
# epoch = 1 loss =0.6941369511623928
# training done
# 55 1
# epoch = 1 loss =0.7011250641267446
# training done
# 56 1
# epoch = 1 loss =0.6969060839060233
# training done
# 57 1
# epoch = 1 loss =0.6935723610720546
# training done
# 58 1
# epoch = 1 loss =0.6993923968975281
# training done
# 59 1
# epoch = 1 loss =0.6942917670783746
# training done
# 60 1
# epoch = 1 loss =0.6938343289244773
# training done
# 61 1
# epoch = 1 loss =0.6945408658132635
# training done
# 62 1
# epoch = 1 loss =0.690983397905415
# training done
# 63 1
# epoch = 1 loss =0.7010717695333166
# training done
# 64 1
# epoch = 1 loss =0.6953247079972431
# training done
# 65 1
# epoch = 1 loss =0.6975964452505018
# training done
# 66 1
# epoch = 1 loss =0.698165427710009
# training done
# 67 1
# epoch = 1 loss =0.6876685492235783
# training done
# 68 1
# epoch = 1 loss =0.692189518452064
# training done
# 69 1
# epoch = 1 loss =0.6866133157494986
# training done
# 70 1
# epoch = 1 loss =0.7045382966021111
# training done
# 71 1
# epoch = 1 loss =0.6921080903686646
# training done
# 72 1
# epoch = 1 loss =0.6943534336382879
# training done
# 73 1
# epoch = 1 loss =0.6942412173202303
# training done
# 74 1
# epoch = 1 loss =0.6872010868497757
# training done
# 75 1
# epoch = 1 loss =0.6985320480564283
# training done
# 76 1
# epoch = 1 loss =0.6953169427366552
# training done
# 77 1
# epoch = 1 loss =0.6965363160402395
# training done
# 78 1
# epoch = 1 loss =0.6993956181903411
# training done
# 79 1
# epoch = 1 loss =0.6942695413168571
# training done
# 80 1
# epoch = 1 loss =0.6962079032994947
# training done
# 81 1
# epoch = 1 loss =0.7009354381677197
# training done
# 82 1
# epoch = 1 loss =0.6906069787611209
# training done
# 83 1
# epoch = 1 loss =0.698386972767328
# training done
# 84 1
# epoch = 1 loss =0.6925352923961126
# training done
# 85 1
# epoch = 1 loss =0.6976551048262758
# training done
# 86 1
# epoch = 1 loss =0.6954247592279929
# training done
# 87 1
# epoch = 1 loss =0.6963274109059938
# training done
# 88 1
# epoch = 1 loss =0.6940279905102302
# training done
# 89 1
# epoch = 1 loss =0.6871293482059948
# training done
# 90 1
# epoch = 1 loss =0.6959294384937681
# training done
# 91 1
# epoch = 1 loss =0.6972738950041065
# training done
# 92 1
# epoch = 1 loss =0.6944645031872366
# training done
# 93 1
# epoch = 1 loss =0.6966992178183641
# training done
# 94 1
# epoch = 1 loss =0.6942262581090971
# training done
# 95 1
# epoch = 1 loss =0.6951844736950546
# training done
# 96 1
# epoch = 1 loss =0.6916525481741984
# training done
# 97 1
# epoch = 1 loss =0.6910405079250084
# training done
# 98 1
# epoch = 1 loss =0.6868214190737918
# training done
# 99 1
# epoch = 1 loss =0.702581367926404
# training done
# 100 1
# epoch = 1 loss =0.6954597683802093
# training done
# 101 1
# epoch = 1 loss =0.6951963740345768
# training done
# 102 1
# epoch = 1 loss =0.693299992514735
# training done
# 103 1
# epoch = 1 loss =0.698967978016558
# training done
# 104 1
# epoch = 1 loss =0.6964043427824967
# training done
# 105 1
# epoch = 1 loss =0.6964421804888103
# training done
# 106 1
# epoch = 1 loss =0.6945766564409674
# training done
# 107 1
# epoch = 1 loss =0.6950399728373902
# training done
# 108 1
# epoch = 1 loss =0.695352773135174
# training done
# 109 1
# epoch = 1 loss =0.6995795012955484
# training done
# 110 1
# epoch = 1 loss =0.6923749491036497
# training done
# 111 1
# epoch = 1 loss =0.6890529030407648
# training done
# 112 1
# epoch = 1 loss =0.6938069004106329
# training done
# 113 1
# epoch = 1 loss =0.6978629401364149
# training done
# 114 1
# epoch = 1 loss =0.6912363352433892
# training done
# 115 1
# epoch = 1 loss =0.6941693304694225
# training done
# 116 1
# epoch = 1 loss =0.6915687484686329
# training done
# 117 1
# epoch = 1 loss =0.7003371952546854
# training done
# 118 1
# epoch = 1 loss =0.6944260586514965
# training done
# 119 1
# epoch = 1 loss =0.6948777930425379
# training done
# 120 1
# epoch = 1 loss =0.688486746448869
# training done
# 121 1
# epoch = 1 loss =0.6950665449672031
# training done
# 122 1
# epoch = 1 loss =0.6982385816323364
# training done
# 123 1
# epoch = 1 loss =0.6939714342392458
# training done
# 124 1
# epoch = 1 loss =0.6925356997373335
# training done
# 125 1
# epoch = 1 loss =0.68906311327598
# training done
# 126 1
# epoch = 1 loss =0.6970702578555803
# training done
# 127 1
# epoch = 1 loss =0.6860306521644874
# training done
# 128 1
# epoch = 1 loss =0.7026077900457317
# training done
# 129 1
# epoch = 1 loss =0.6953136058941743
# training done
# 130 1
# epoch = 1 loss =0.6956292284417365
# training done
# 131 1
# epoch = 1 loss =0.6944545440886497
# training done
# 132 1
# epoch = 1 loss =0.6955594494966383
# training done
# 133 1
# epoch = 1 loss =0.6932919382897894
# training done
# 134 1
# epoch = 1 loss =0.6888793050461431
# training done
# 135 1
# epoch = 1 loss =0.6970708061383546
# training done
# 136 1
# epoch = 1 loss =0.6942646496378542
# training done
# 137 1
# epoch = 1 loss =0.6968555491747417
# training done
# 138 1
# epoch = 1 loss =0.696899070344569
# training done
# 139 1
# epoch = 1 loss =0.6965302432490275
# training done
# 140 1
# epoch = 1 loss =0.6948390666126172
# training done
# 141 1
# epoch = 1 loss =0.6954815753825827
# training done
# 142 1
# epoch = 1 loss =0.6910957482431138
# training done
# 143 1
# epoch = 1 loss =0.6968803977225622
# training done
# 144 1
# epoch = 1 loss =0.6989495826184339
# training done
# 145 1
# epoch = 1 loss =0.6898095556567923
# training done
# 146 1
# epoch = 1 loss =0.6948079869942699
# training done
# 147 1
# epoch = 1 loss =0.6920966232288932
# training done
# 148 1
# epoch = 1 loss =0.6966439179137773
# training done
# 149 1
# epoch = 1 loss =0.6933922544769523
# training done
# 150 1
# epoch = 1 loss =0.6980211031148801
# training done
# 151 1
# epoch = 1 loss =0.6970353889128029
# training done
# 152 1
# epoch = 1 loss =0.6932642717869761
# training done
# 153 1
# epoch = 1 loss =0.6903396614440637
# training done
# 154 1
# epoch = 1 loss =0.7005471019762485
# training done
# 155 1
# epoch = 1 loss =0.6932648320350728
# training done
# 156 1
# epoch = 1 loss =0.6933255031699312
# training done
# 157 1
# epoch = 1 loss =0.6963163898244155
# training done
# 158 1
# epoch = 1 loss =0.6976374703540916
# training done
# 159 1
# epoch = 1 loss =0.6958425582658984
# training done
# 160 1
# epoch = 1 loss =0.6829090593569295
# training done
# 161 1
# epoch = 1 loss =0.7037524156155927
# training done
# 162 1
# epoch = 1 loss =0.6972432021996079
# training done
# 163 1
# epoch = 1 loss =0.6988950251942896
# training done
# 164 1
# epoch = 1 loss =0.6952423934220165
# training done
# 165 1
# epoch = 1 loss =0.6933963334586593
# training done
# 166 1
# epoch = 1 loss =0.6937778859120853
# training done
# 167 1
# epoch = 1 loss =0.6954759528287873
# training done
# 168 1
# epoch = 1 loss =0.6926261612590978
# training done
# 169 1
# epoch = 1 loss =0.6965451642532966
# training done
# 170 1
# epoch = 1 loss =0.695160597297357
# training done
# 171 1
# epoch = 1 loss =0.6950798887499324
# training done
# 172 1
# epoch = 1 loss =0.6894318729141609
# training done
# 173 1
# epoch = 1 loss =0.6992656274624902
# training done
# 174 1

# %%
pred_vals = net_4.predict(np.asarray(X_test))
# for test_data in X_test:
#     pred_vals.append(net_3.predict(np.asarray(test_data)))
    
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,pred_vals))
from sklearn.metrics import f1_score
print(f1_score(y_test, pred_vals, average='macro'))
f1_score(y_test, pred_vals, average='micro')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a3b99f9ec36> in <module>()
# ----> 1 pred_vals = net_4.predict(np.asarray(X_test))
#       2 # for test_data in X_test:
#       3 #     pred_vals.append(net_3.predict(np.asarray(test_data)))
#       4
#       5 from sklearn.metrics import accuracy_score
#
# NameError: name 'net_4' is not defined

# %%
np.where(pred_vals == 1)
# Out:
# (array([], dtype=int64),)

# %%
# import numpy as np
# from sklearn.decomposition import PCA
# pca = PCA(n_components=400)
# total_data = pca.fit_transform(total_data)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model1 = keras.Sequential([
    keras.layers.Dense(200, input_shape=(1024,),activation=tf.nn.relu),
    keras.layers.Dense(50, activation=tf.nn.relu),
    keras.layers.Dense(50, activation=tf.nn.relu),
    keras.layers.Dense(2, activation=tf.nn.softmax)
])

# %%
model1.compile(optimizer=tf.train.AdamOptimizer(), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# model1.compile(optimizer='sgd', 
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# %%
model1.fit(np.asarray(X_train[:500]),y_train[:500],epochs=20)
# Out:
# Epoch 1/20
# 500/500 [==============================] - 1s 1ms/step - loss: 8.1880 - acc: 0.4920
# Epoch 2/20
# 500/500 [==============================] - 0s 174us/step - loss: 8.1880 - acc: 0.4920
# Epoch 3/20
# 500/500 [==============================] - 0s 131us/step - loss: 8.1880 - acc: 0.4920
# Epoch 4/20
# 500/500 [==============================] - 0s 150us/step - loss: 8.1880 - acc: 0.4920
# Epoch 5/20
# 500/500 [==============================] - 0s 180us/step - loss: 8.1880 - acc: 0.4920
# Epoch 6/20
# 500/500 [==============================] - 0s 151us/step - loss: 8.1880 - acc: 0.4920
# Epoch 7/20
# 500/500 [==============================] - 0s 132us/step - loss: 8.1880 - acc: 0.4920
# Epoch 8/20
# 500/500 [==============================] - 0s 143us/step - loss: 8.1880 - acc: 0.4920
# Epoch 9/20
# 500/500 [==============================] - 0s 170us/step - loss: 8.1880 - acc: 0.4920
# Epoch 10/20
# 500/500 [==============================] - 0s 169us/step - loss: 8.1880 - acc: 0.4920
# Epoch 11/20
# 500/500 [==============================] - 0s 125us/step - loss: 8.1880 - acc: 0.4920
# Epoch 12/20
# 500/500 [==============================] - 0s 158us/step - loss: 8.1880 - acc: 0.4920
# Epoch 13/20
# 500/500 [==============================] - 0s 172us/step - loss: 8.1880 - acc: 0.4920
# Epoch 14/20
# 500/500 [==============================] - 0s 150us/step - loss: 8.1880 - acc: 0.4920
# Epoch 15/20
# 500/500 [==============================] - 0s 149us/step - loss: 8.1880 - acc: 0.4920
# Epoch 16/20
# 500/500 [==============================] - 0s 165us/step - loss: 8.1880 - acc: 0.4920
# Epoch 17/20
# 500/500 [==============================] - 0s 141us/step - loss: 8.1880 - acc: 0.4920
# Epoch 18/20
# 500/500 [==============================] - 0s 170us/step - loss: 8.1880 - acc: 0.4920
# Epoch 19/20
# 500/500 [==============================] - 0s 145us/step - loss: 8.1880 - acc: 0.4920
# Epoch 20/20
# 500/500 [==============================] - 0s 164us/step - loss: 8.1880 - acc: 0.4920

# %%
import cv2

# %%
cv2.resize()
